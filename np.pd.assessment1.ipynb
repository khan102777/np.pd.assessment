# %%
import pandas as pd

# %%
file1 = pd.read_csv("C:\\Users\\This Pc\\OneDrive\\Desktop\\banklist.csv")

# %%
file1
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
# ...

# %%
file1.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 2  58302                         Whitney Bank    28-Apr-17    26-Jul-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %%
file1.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
file1['ST'].unique()
# Out:
# array(['IL', 'WI', 'LA', 'UT', 'NJ', 'AR', 'GA', 'PA', 'TN', 'WA', 'CO',
#        'PR', 'FL', 'MN', 'CA', 'MD', 'OK', 'OH', 'SC', 'VA', 'ID', 'TX',
#        'CT', 'AZ', 'NV', 'NC', 'KY', 'MO', 'KS', 'AL', 'MI', 'IN', 'IA',
#        'NE', 'MS', 'NM', 'OR', 'NY', 'MA', 'SD', 'WY', 'WV', 'NH', 'HI'],
#       dtype=object)

# %%
file1['ST'].tolist()
# Out:
# ['IL',
#  'WI',
#  'LA',
#  'UT',
#  'IL',
#  'NJ',
#  'AR',
#  'GA',
#  'PA',
#  'TN',
#  'WI',
#  'WA',
#  'GA',
#  'CO',
#  'IL',
#  'PR',
#  'GA',
#  'IL',
#  'FL',
#  'MN',
#  'CA',
#  'IL',
#  'MD',
#  'IL',
#  'GA',
#  'OK',
#  'FL',
#  'IL',
#  'MD',
#  'OH',
#  'IL',
#  'SC',
#  'PA',
#  'VA',
#  'ID',
#  'OK',
#  'IL',
#  'TX',
#  'FL',
#  'TX',
#  'CT',
#  'AZ',
#  'TN',
#  'WI',
#  'FL',
#  'TN',
#  'NV',
#  'WI',
#  'AZ',
#  'GA',
#  'NC',
#  'GA',
#  'NC',
#  'FL',
#  'FL',
#  'KY',
#  'AZ',
#  'GA',
#  'IL',
#  'MN',
#  'WA',
#  'MO',
#  'GA',
#  'IL',
#  'FL',
#  'PA',
#  'MO',
#  'FL',
#  'FL',
#  'IL',
#  'MO',
#  'MN',
#  'IL',
#  'GA',
#  'IL',
#  'KS',
#  'GA',
#  'GA',
#  'FL',
#  'MO',
#  'GA',
#  'TN',
#  'GA',
#  'FL',
#  'NC',
#  'IL',
#  'SC',
#  'OK',
#  'AL',
#  'FL',
#  'CA',
#  'SC',
#  'MN',
#  'MD',
#  'MD',
#  'NJ',
#  'MI',
#  'IL',
#  'GA',
#  'IL',
#  'GA',
#  'MN',
#  'GA',
#  'IN',
#  'IL',
#  'TN',
#  'MN',
#  'TN',
#  'FL',
#  'PA',
#  'GA',
# ...

# %%
file1['ST'].value_counts().head()
# Out:
# ST
# GA    93
# FL    75
# IL    68
# CA    41
# MN    23
# Name: count, dtype: int64

# %%
file1['Acquiring Institution'].value_counts().head()
# Out:
# Acquiring Institution
# No Acquirer                            31
# State Bank and Trust Company           12
# First-Citizens Bank & Trust Company    11
# Ameris Bank                            10
# U.S. Bank N.A.                          9
# Name: count, dtype: int64

# %%
acqbysbt = file1[file1['Acquiring Institution'] == 'State Bank of Texas']
acqbysbt
# Out:
#                                  Bank Name     City  ST   CERT  \
# 4            Seaway Bank and Trust Company  Chicago  IL  19328
# 21   The National Republic Bank of Chicago  Chicago  IL    916
# 450         Millennium State Bank of Texas   Dallas  TX  57667
#
#     Acquiring Institution Closing Date Updated Date
# 4     State Bank of Texas    27-Jan-17    18-May-17
# 21    State Bank of Texas    24-Oct-14     6-Jan-16
# 450   State Bank of Texas     2-Jul-09    26-Oct-12

# %%
a=acqbysbt['Bank Name'].unique()
print(f"Total distinct banks: {len(a)}")
# Out:
# Total distinct banks: 3

# %%
acqbysbtintx = acqbysbt[acqbysbt['ST'] == 'TX']
acqbysbtintx
# Out:
#                           Bank Name    City  ST   CERT Acquiring Institution  \
# 450  Millennium State Bank of Texas  Dallas  TX  57667   State Bank of Texas
#
#     Closing Date Updated Date
# 450     2-Jul-09    26-Oct-12

# %%
b=acqbysbtintx['Bank Name'].unique()
print(f"Total distinct banks: {len(b)}")
# Out:
# Total distinct banks: 1

# %%
cabank = file1[file1['ST'] == 'CA']
cabank
# Out:
#                                     Bank Name              City  ST   CERT  \
# 20     Frontier Bank, FSB D/B/A El Paseo Bank       Palm Desert  CA  34738
# 90                  Palm Desert National Bank       Palm Desert  CA  23632
# 131      Citizens Bank of Northern California       Nevada City  CA  33983
# 182                  San Luis Trust Bank, FSB   San Luis Obispo  CA  34783
# 183                          Charter Oak Bank              Napa  CA  57855
# 186                      Canyon National Bank      Palm Springs  CA  34692
# 218            First Vietnamese American Bank       Westminster  CA  57885
# 220                   Western Commercial Bank    Woodland Hills  CA  58087
# 243                        Sonoma Valley Bank            Sonoma  CA  27259
# 244                           Los Padres Bank           Solvang  CA  32165
# 245                      Butte Community Bank             Chico  CA  33219
# ...

# %%
ab=cabank['City'].unique()
# Out:
# array(['Palm Desert', 'Nevada City', 'San Luis Obispo', 'Napa',
#        'Palm Springs', 'Westminster', 'Woodland Hills', 'Sonoma',
#        'Solvang', 'Chico', 'Stockton', 'Granite Bay', 'San Diego',
#        'San Rafael', 'Oakland', 'La Jolla', 'Los Angeles', 'Santa Monica',
#        'San Clemente', 'San Francisco', 'Bakersfield', 'Ventura',
#        'Temecula', 'Rancho Cucamonga', 'Irvine', 'Calabasas', 'Merced',
#        'Culver City', 'Redlands', 'Pomona', 'Newport Beach', 'Pasadena',
#        'Torrance'], dtype=object)

# %%
cabank['City'].value_counts().head()
# Out:
# City
# Los Angeles      4
# San Diego        2
# Newport Beach    2
# San Francisco    2
# La Jolla         2
# Name: count, dtype: int64
